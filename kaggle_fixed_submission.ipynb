# %% [markdown]
# # Fixed Kaggle Notebook
#
# Notebook ini sudah dibenarkan supaya:
# - bisa jalan di Kaggle maupun lokal,
# - tidak bergantung GPU CatBoost,
# - langsung menghasilkan `submission.csv`,
# - tidak ada cell broken dari XGBoost / LightGBM.

# %%
# 1) IMPORT
import os
import warnings
from pathlib import Path

warnings.filterwarnings("ignore")

import numpy as np
import pandas as pd

from sklearn.model_selection import StratifiedKFold
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from catboost import CatBoostClassifier

pd.set_option("display.max_columns", 200)
pd.set_option("display.width", 150)

# %%
# 2) FIND DATA DIRECTORY (LOCAL OR KAGGLE)
def find_data_dir() -> Path:
    candidates = [
        Path("/kaggle/input/competitions/datathon-playground-2026"),
        Path("/kaggle/input/datathon-playground-2026"),
        Path(r"D:\UI"),
        Path.cwd(),
    ]

    for c in candidates:
        if (c / "train.csv").exists() and (c / "test.csv").exists() and (c / "sample_submission.csv").exists():
            return c

    kaggle_input = Path("/kaggle/input")
    if kaggle_input.exists():
        for p in kaggle_input.rglob("train.csv"):
            d = p.parent
            if (d / "test.csv").exists() and (d / "sample_submission.csv").exists():
                return d

    raise FileNotFoundError(
        "Could not find train.csv, test.csv, and sample_submission.csv. "
        "Please attach the competition dataset (Kaggle) or place files in D:\\UI."
    )

DATA_DIR = find_data_dir()
print("Using DATA_DIR:", DATA_DIR)

train = pd.read_csv(DATA_DIR / "train.csv")
test = pd.read_csv(DATA_DIR / "test.csv")
sample_submission = pd.read_csv(DATA_DIR / "sample_submission.csv")

print("train:", train.shape)
print("test :", test.shape)
print("sub  :", sample_submission.shape)
display(train.head())
# Out:
# Using DATA_DIR: D:\UI
# train: (3200, 43)
# test : (800, 42)
# sub  : (800, 2)
#    id  nilai_minggu_01  nilai_minggu_02  nilai_minggu_03  nilai_minggu_04  nilai_minggu_05  nilai_minggu_06  nilai_minggu_07  nilai_minggu_08  \
# 0   0              2.6              6.4              3.6              1.0              4.4              8.5             -4.0             -0.1
# 1   1             -0.3              5.7              1.7              1.3              6.1              5.8             -0.1             -3.8
# 2   2             -4.8             -0.8             -3.5             -6.3             -3.7             -1.5             10.7              8.7
# 3   4              4.7              1.1              2.1              0.2              1.9              1.4             -0.5             -0.3
# 4   5             13.3              3.5              3.4              4.1              6.2              8.7             -5.0             -6.1
#
#    nilai_minggu_09  nilai_minggu_10  nilai_minggu_11  nilai_minggu_12  skor_motivasi  skor_kedisiplinan  aktivitas_hari_01  aktivitas_hari_02  \
# 0             -4.7              1.0             -4.7             -5.1          -0.53              -0.33               64.3               42.7
# 1             -3.1             -3.1             -1.0              1.0          -2.24               1.82               27.8               51.6
# 2              5.8              5.2              7.2              9.9          -1.18              -1.34               33.9               50.4
# 3              0.5             -1.4             -1.2              3.6          -0.60               0.69               51.0               48.0
# 4             -5.2             -8.2             -7.1             -6.6          -1.19              -0.67               59.2               43.0
#
#    aktivitas_hari_03  aktivitas_hari_04  aktivitas_hari_05  aktivitas_hari_06  aktivitas_hari_07  aktivitas_hari_08  aktivitas_hari_09  \
# 0               42.4               65.4               77.6               61.2               36.8               34.4               51.8
# 1               53.6               56.4               40.7               68.0               66.4               30.5               51.8
# 2               50.0               36.4               73.0               66.4               36.6               62.2               60.5
# 3               36.5               31.8               53.0               60.7               76.7               65.1               51.1
# 4               43.6               64.6               57.7               42.2               57.7               57.7               47.9
#
#    aktivitas_hari_10  aktivitas_hari_11  aktivitas_hari_12  aktivitas_hari_13  aktivitas_hari_14  aktivitas_hari_15  aktivitas_hari_16  \
# 0               89.6               55.2               44.7               42.0               46.7               69.2               46.9
# 1               74.3               61.4               41.6               38.7               72.0               31.7               32.6
# 2               35.9               49.0               63.3               43.7               47.2               53.5               44.9
# 3               39.0               36.4               41.9               49.1               56.2               70.6               64.5
# 4               37.2               62.3               77.4               36.5               42.2               58.5               52.8
#
#    tugas_selesai  tugas_diberikan  kelas  urutan_ujian  skor_tryout  jarak_rumah_km  skor_ekstrakurikuler  indeks_kehadiran  skor_literasi  \
# 0              8                9    114        0.0817         72.3            0.46                  0.00             -0.38          -0.24
# 1             46               85    301        0.3388         41.4           -1.29                  0.51              0.86          -0.70
# 2             23               75     28        0.0517         73.2           -0.03                 -0.33              0.14           0.80
# 3             95              110    580        0.0310         59.1           -0.20                  0.24              1.68          -0.44
# 4             24               32    127        0.5829         60.7            1.06                  0.49              0.42          -1.36
#
#    jumlah_saudara  skor_minat_belajar  target
# 0           -0.70               -0.62       3
# 1           -1.04                2.15       1
# 2            0.26               -0.57       3
# 3            1.32               -0.64       1
# 4           -0.45               -1.92       3

# %%
# 3) DETECT TARGET & ID COLUMNS
id_col = sample_submission.columns[0]
sub_target_col = sample_submission.columns[1]

possible_targets = [c for c in train.columns if c not in test.columns]

if len(possible_targets) == 1:
    target_col = possible_targets[0]
else:
    non_id_candidates = [c for c in possible_targets if c != id_col]
    target_col = non_id_candidates[0] if len(non_id_candidates) > 0 else possible_targets[0]

print("id_col    =", id_col)
print("target_col=", target_col)
print("sub_target=", sub_target_col)
# Out:
# id_col    = id
# target_col= target
# sub_target= target

# %%
# 4) FEATURE ENGINEERING
def add_prefix_features(df: pd.DataFrame, prefix: str, new_name: str) -> pd.DataFrame:
    cols = [c for c in df.columns if c.startswith(prefix)]
    if len(cols) == 0:
        return df

    num = df[cols].apply(pd.to_numeric, errors="coerce")

    df[f"{new_name}_count"] = num.notna().sum(axis=1)
    df[f"{new_name}_mean"] = num.mean(axis=1)
    df[f"{new_name}_std"] = num.std(axis=1)
    df[f"{new_name}_min"] = num.min(axis=1)
    df[f"{new_name}_max"] = num.max(axis=1)
    df[f"{new_name}_range"] = df[f"{new_name}_max"] - df[f"{new_name}_min"]
    df[f"{new_name}_sum"] = num.sum(axis=1)

    def slope(row):
        y = row.values.astype(float)
        mask = ~np.isnan(y)
        y = y[mask]
        if len(y) < 2:
            return 0.0
        x = np.arange(len(y))
        return np.polyfit(x, y, 1)[0]

    df[f"{new_name}_trend"] = num.apply(slope, axis=1)

    first_col = cols[0]
    last_col = cols[-1]
    df[f"{new_name}_first"] = pd.to_numeric(df[first_col], errors="coerce")
    df[f"{new_name}_last"] = pd.to_numeric(df[last_col], errors="coerce")
    df[f"{new_name}_delta"] = df[f"{new_name}_last"] - df[f"{new_name}_first"]

    return df


def feature_engineering(df: pd.DataFrame) -> pd.DataFrame:
    df = df.copy()

    df = add_prefix_features(df, "nilai_minggu_", "nm")
    df = add_prefix_features(df, "aktivitas_hari_", "ah")

    if "tugas_selesai" in df.columns and "tugas_diberikan" in df.columns:
        df["task_completion_ratio"] = df["tugas_selesai"] / (df["tugas_diberikan"] + 1e-6)
        df["task_missing"] = df["tugas_diberikan"] - df["tugas_selesai"]

    if "skor_motivasi" in df.columns and "skor_kedisiplinan" in df.columns:
        df["motivasi_x_disiplin"] = df["skor_motivasi"] * df["skor_kedisiplinan"]
        df["motivasi_plus_disiplin"] = df["skor_motivasi"] + df["skor_kedisiplinan"]
        df["motivasi_minus_disiplin"] = df["skor_motivasi"] - df["skor_kedisiplinan"]

    if "skor_tryout" in df.columns:
        if "nm_mean" in df.columns:
            df["tryout_vs_nm_mean"] = df["skor_tryout"] - df["nm_mean"]
        if "nm_last" in df.columns:
            df["tryout_vs_nm_last"] = df["skor_tryout"] - df["nm_last"]

    if "nm_trend" in df.columns:
        df["trend_abs"] = df["nm_trend"].abs()

    if "ah_trend" in df.columns:
        df["activity_trend_abs"] = df["ah_trend"].abs()

    df["missing_count"] = df.isna().sum(axis=1)

    return df

# %%
# 5) SPLIT X / y + APPLY FEATURE ENGINEERING
X = train.drop(columns=[target_col]).copy()
y = train[target_col].copy()
X_test = test.copy()

X = X.drop(columns=[id_col], errors="ignore")
X_test = X_test.drop(columns=[id_col], errors="ignore")

X = feature_engineering(X)
X_test = feature_engineering(X_test)

print("X shape after FE    :", X.shape)
print("X_test shape after FE:", X_test.shape)
# Out:
# X shape after FE    : (3200, 73)
# X_test shape after FE: (800, 73)

# %%
# 6) CLEANING
cat_cols = [c for c in X.columns if X[c].dtype == "object" or str(X[c].dtype) == "category" or X[c].dtype == "bool"]
num_cols = [c for c in X.columns if c not in cat_cols]

for c in cat_cols:
    X[c] = X[c].astype("string").fillna("MISSING")
    X_test[c] = X_test[c].astype("string").fillna("MISSING")

for c in num_cols:
    med = X[c].median()
    X[c] = X[c].fillna(med)
    X_test[c] = X_test[c].fillna(med)

print("categorical:", len(cat_cols))
print("numerical   :", len(num_cols))
# Out:
# categorical: 0
# numerical   : 73

# %%
# 7) ENCODE TARGET
le = LabelEncoder()
y_enc = le.fit_transform(y.astype(str))

print("classes:", list(le.classes_))
print(pd.Series(y_enc).value_counts().sort_index())
# Out:
# classes: ['0', '1', '2', '3']
# 0    813
# 1    796
# 2    784
# 3    807
# Name: count, dtype: int64

# %%
# 8) TRAIN CATBOOST ON CPU + CROSS VALIDATION
FAST_MODE = False   # True = lebih cepat, False = lebih serius

n_splits = 3 if FAST_MODE else 5
iterations = 1200 if FAST_MODE else 3000

skf = StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=42)

oof_pred = np.zeros(len(X), dtype=int)
test_pred_proba = np.zeros((len(X_test), len(le.classes_)))
scores = []

cat_features = [X.columns.get_loc(c) for c in cat_cols]

for fold, (tr_idx, va_idx) in enumerate(skf.split(X, y_enc), 1):
    X_tr, X_va = X.iloc[tr_idx].copy(), X.iloc[va_idx].copy()
    y_tr, y_va = y_enc[tr_idx], y_enc[va_idx]

    model = CatBoostClassifier(
        loss_function="MultiClass",
        eval_metric="Accuracy",
        iterations=iterations,
        learning_rate=0.03,
        depth=8,
        l2_leaf_reg=6,
        random_seed=42 + fold,
        auto_class_weights="Balanced",
        od_type="Iter",
        od_wait=200,
        verbose=200,
        allow_writing_files=False
    )

    model.fit(
        X_tr, y_tr,
        cat_features=cat_features,
        eval_set=(X_va, y_va),
        use_best_model=True
    )

    va_pred = model.predict(X_va).astype(int).ravel()
    fold_score = accuracy_score(y_va, va_pred)
    scores.append(fold_score)
    oof_pred[va_idx] = va_pred

    test_pred_proba += model.predict_proba(X_test) / n_splits

    print(f"Fold {fold} Accuracy: {fold_score:.5f}")

print("\nCV mean accuracy:", np.mean(scores))
print("CV std accuracy :", np.std(scores))
print("OOF accuracy    :", accuracy_score(y_enc, oof_pred))
# Out:
# 0:	learn: 0.4901763	test: 0.4032492	best: 0.4032492 (0)	total: 239ms	remaining: 11m 56s
# 200:	learn: 0.8340524	test: 0.4791006	best: 0.4850973 (32)	total: 21.3s	remaining: 4m 56s
# 400:	learn: 0.9400409	test: 0.4964719	best: 0.5105820 (362)	total: 42.8s	remaining: 4m 37s
# 600:	learn: 0.9781419	test: 0.5135497	best: 0.5198311 (581)	total: 1m 3s	remaining: 4m 14s
# 800:	learn: 0.9933797	test: 0.5230323	best: 0.5277137 (782)	total: 1m 23s	remaining: 3m 50s
# 1000:	learn: 0.9992248	test: 0.5214279	best: 0.5277527 (972)	total: 1m 46s	remaining: 3m 32s
# 1200:	learn: 1.0000000	test: 0.5246353	best: 0.5325270 (1132)	total: 2m 8s	remaining: 3m 12s
# 1400:	learn: 1.0000000	test: 0.5293557	best: 0.5340880 (1282)	total: 2m 30s	remaining: 2m 52s
# Stopped by overfitting detector  (200 iterations wait)
#
# bestTest = 0.53408802
# bestIteration = 1282
#
# Shrink model to first 1283 iterations.
# Fold 1 Accuracy: 0.53594
# 0:	learn: 0.4960472	test: 0.4235173	best: 0.4235173 (0)	total: 128ms	remaining: 6m 23s
# 200:	learn: 0.8121803	test: 0.5022622	best: 0.5022622 (200)	total: 25.4s	remaining: 5m 53s
# 400:	learn: 0.9283270	test: 0.5275802	best: 0.5275802 (400)	total: 49.5s	remaining: 5m 20s
# 600:	learn: 0.9800565	test: 0.5494256	best: 0.5525566 (586)	total: 1m 12s	remaining: 4m 50s
# 800:	learn: 0.9930030	test: 0.5651263	best: 0.5651514 (772)	total: 1m 32s	remaining: 4m 14s
# 1000:	learn: 0.9988444	test: 0.5666767	best: 0.5699110 (832)	total: 1m 52s	remaining: 3m 45s
# Stopped by overfitting detector  (200 iterations wait)
#
# bestTest = 0.5699109537
# bestIteration = 832
#
# Shrink model to first 833 iterations.
# Fold 2 Accuracy: 0.57188
# 0:	learn: 0.4934794	test: 0.3931342	best: 0.3931342 (0)	total: 105ms	remaining: 5m 15s
# 200:	learn: 0.8321109	test: 0.5064879	best: 0.5113317 (174)	total: 20.5s	remaining: 4m 45s
# 400:	learn: 0.9329764	test: 0.5207118	best: 0.5301768 (296)	total: 41.6s	remaining: 4m 29s
# 600:	learn: 0.9784893	test: 0.5427252	best: 0.5489383 (557)	total: 1m 5s	remaining: 4m 19s
# 800:	learn: 0.9961180	test: 0.5443099	best: 0.5568001 (716)	total: 1m 27s	remaining: 3m 59s
# Stopped by overfitting detector  (200 iterations wait)
#
# bestTest = 0.5568000966
# bestIteration = 716
#
# Shrink model to first 717 iterations.
# Fold 3 Accuracy: 0.55937
# 0:	learn: 0.4798020	test: 0.3986419	best: 0.3986419 (0)	total: 113ms	remaining: 5m 37s
# 200:	learn: 0.8231150	test: 0.4648673	best: 0.4710247 (68)	total: 22.8s	remaining: 5m 17s
# 400:	learn: 0.9305734	test: 0.5027226	best: 0.5104996 (382)	total: 45.2s	remaining: 4m 52s
# 600:	learn: 0.9773031	test: 0.5120285	best: 0.5167194 (581)	total: 1m 8s	remaining: 4m 32s
# 800:	learn: 0.9945681	test: 0.5197399	best: 0.5245027 (727)	total: 1m 29s	remaining: 4m 6s
# 1000:	learn: 0.9984427	test: 0.5277362	best: 0.5307758 (928)	total: 1m 52s	remaining: 3m 44s
# Stopped by overfitting detector  (200 iterations wait)
#
# bestTest = 0.5307757667
# bestIteration = 928
#
# Shrink model to first 929 iterations.
# Fold 4 Accuracy: 0.53281
# 0:	learn: 0.4751985	test: 0.4359538	best: 0.4359538 (0)	total: 116ms	remaining: 5m 46s
# 200:	learn: 0.8047082	test: 0.4803338	best: 0.4836051 (188)	total: 23.5s	remaining: 5m 27s
# 400:	learn: 0.9181906	test: 0.5165092	best: 0.5165092 (400)	total: 46.8s	remaining: 5m 3s
# 600:	learn: 0.9785367	test: 0.5403261	best: 0.5450198 (552)	total: 1m 10s	remaining: 4m 40s
# 800:	learn: 0.9953240	test: 0.5464958	best: 0.5496041 (799)	total: 1m 34s	remaining: 4m 18s
# 1000:	learn: 0.9996013	test: 0.5463205	best: 0.5558649 (974)	total: 1m 55s	remaining: 3m 51s
# Stopped by overfitting detector  (200 iterations wait)
#
# bestTest = 0.5558648636
# bestIteration = 974
#
# Shrink model to first 975 iterations.
# Fold 5 Accuracy: 0.55781
#
# CV mean accuracy: 0.5515625
# CV std accuracy : 0.014888911561964502
# OOF accuracy    : 0.5515625

# %%
# 9) EVALUATION
print(classification_report(y_enc, oof_pred))
print(confusion_matrix(y_enc, oof_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.66      0.71      0.68       813
#            1       0.41      0.38      0.40       796
#            2       0.43      0.38      0.41       784
#            3       0.65      0.73      0.69       807
#
#     accuracy                           0.55      3200
#    macro avg       0.54      0.55      0.54      3200
# weighted avg       0.54      0.55      0.54      3200
#
# [[574 181  48  10]
#  [228 304 193  71]
#  [ 56 199 299 230]
#  [ 17  53 149 588]]

# %%
# 10) FEATURE IMPORTANCE
fi = pd.DataFrame({
    "feature": X.columns,
    "importance": model.get_feature_importance()
}).sort_values("importance", ascending=False)

display(fi.head(30))
# Out:
#                    feature  importance
# 63   task_completion_ratio    9.542628
# 65     motivasi_x_disiplin    8.405719
# 70               trend_abs    4.234207
# 20       aktivitas_hari_07    2.584867
# 43                  nm_std    2.543875
# 25       aktivitas_hari_12    2.454372
# 23       aktivitas_hari_10    2.365899
# 21       aktivitas_hari_08    2.359071
# 28       aktivitas_hari_15    2.281099
# 24       aktivitas_hari_11    2.093485
# 26       aktivitas_hari_13    1.900270
# 19       aktivitas_hari_06    1.876875
# 18       aktivitas_hari_05    1.845597
# 64            task_missing    1.801398
# 27       aktivitas_hari_14    1.795150
# 16       aktivitas_hari_03    1.738965
# 17       aktivitas_hari_04    1.733820
# 46                nm_range    1.629045
# 15       aktivitas_hari_02    1.611505
# 37        indeks_kehadiran    1.540763
# 44                  nm_min    1.525901
# 22       aktivitas_hari_09    1.448266
# 38           skor_literasi    1.423970
# 69       tryout_vs_nm_last    1.379134
# 66  motivasi_plus_disiplin    1.300348
# 40      skor_minat_belajar    1.282658
# 39          jumlah_saudara    1.269353
# 33            urutan_ujian    1.170281
# 42                 nm_mean    1.169921
# 32                   kelas    1.160024

# %%
# 11) CREATE SUBMISSION FILE
final_pred_idx = np.argmax(test_pred_proba, axis=1)
final_pred = le.inverse_transform(final_pred_idx)

submission = sample_submission.copy()
submission[sub_target_col] = final_pred
submission.to_csv("submission.csv", index=False)

display(submission.head())
print("Saved: submission.csv")
print(pd.Series(final_pred).value_counts())
# Out:
#    id target
# 0   3      0
# 1  12      2
# 2  14      3
# 3  18      3
# 4  28      0
# Saved: submission.csv
# 3    209
# 0    201
# 2    201
# 1    189
# Name: count, dtype: int64

# %%
print ("Done.")
# Out:
# Done.
